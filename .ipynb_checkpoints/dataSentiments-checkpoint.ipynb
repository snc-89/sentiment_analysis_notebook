# %%
import json
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import wikipedia
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn.feature_selection import RFE, RFECV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import re
from pandas.plotting import register_matplotlib_converters
from sklearn.utils import resample
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans

# %%
vids = pd.read_csv('files/labeled_vids.csv')
scores = pd.read_csv('data/raw_scores.csv')

# %%
vids = vids.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1)

# %%
vids.groupby(['class']).mean()
# Out:
#        date  title  viewCount  commentCount  likeCount  dislikeCount  ratio  \
# class
# 0       136    136        136           136        136           136    136
# 1       301    301        301           301        301           301    301
# 2       555    555        555           555        555           555    555
# 3       154    154        154           154        154           154    154
# 4       156    156        156           156        156           156    156
# 5        92     92         92            92         92            92     92
#
#        sentiment  magnitude
# class
# 0            136        136
# 1            301        301
# 2            555        555
# 3            154        154
# 4            156        156
# 5             92         92

# %%
scores = scores.drop(['Unnamed: 0'],axis=1)

# %%
len(scores[scores['sentiment'] == 0.0])
scores = scores.drop(scores[(scores.magnitude == 0.0) & (scores.sentiment==0.0)].index)

# %%
len(scores)
# Out:
# 3231100

# %%
scores.groupby(['idx']).mean()
# Out:
#       magnitude  sentiment
# idx
# 0     36.779625   0.201339
# 1     40.918090   0.155104
# 2     37.651514   0.173865
# 3     54.128431   0.119020
# 4     37.703111   0.186889
# 5     43.958395   0.162840
# 6     43.306250   0.138958
# 7     32.175652   0.153043
# 8     33.577826   0.053913
# 9     39.613235   0.125294
# 10    39.164186   0.230930
# 11    32.818113   0.193019
# 12    36.092105   0.195789
# 13    35.575333   0.134333
# 14    41.901111   0.202778
# 15    41.719968   0.185617
# 16    36.604565   0.156957
# 17    35.467143   0.199643
# 18    37.670893   0.168571
# 19    40.371961   0.185294
# 20    46.337011   0.137816
# 21    40.543645   0.167741
# 22    47.667905   0.152587
# 23    46.998919   0.057973
# 24    46.849952   0.155913
# 25    41.465152   0.235152
# 26    46.944639   0.081546
# 27    44.041194   0.207761
# 28    44.316471   0.243529
# 29    39.695812   0.152009
# ...         ...        ...
# 1364  43.788259   0.164332
# 1365  52.619167   0.213625
# ...

# %%
vids.groupby(['class'])['sentiment','magnitude'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-89f85d203ecc> in <module>
# ----> 1 vids.groupby(['class'])['sentiment','magnitude'].mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     263                 bad_keys = list(set(key).difference(self.obj.columns))
#     264                 raise KeyError("Columns not found: {missing}"
# --> 265                                .format(missing=str(bad_keys)[1:-1]))
#     266             return self._gotitem(list(key), ndim=2)
#     267
#
# KeyError: "Columns not found: 'magnitude', 'sentiment'"

# %%
vids.groupby(['class'])['sentiment','magnitude'].mean()
# Out:
#        sentiment  magnitude
# class
# 0       0.155819  48.237256
# 1       0.153134  42.708911
# 2       0.152238  43.109940
# 3       0.165215  53.765093
# 4       0.168404  45.932069
# 5       0.141137  56.102351

# %%
vids['magnitude'] = scores.groupby(['idx']).mean()['magnitude']
vids['sentiment'] = scores.groupby(['idx']).mean()['sentiment']

# %%
scores.to_csv('files/raw_scores_sans_zeros.csv')

# %%
vids = vids.drop(['Unnamed: 0','Unnamed: 0.1','sentiment','magnitude'],axis=1)

# %%
thing = scores.groupby(['idx']).describe()

# %%
type(thing)
# Out:
# pandas.core.frame.DataFrame

# %%
cols = ['magCount','magMean','magStd','magMin',
        'magLq','magMedian','magUq','magMax',
        'sentCount','sentMean','sentStd','sentMin',
        'sentLq','sentMedian','sentUq','sentMax']
thing.columns = cols

# %%
thing
# Out:
#       magCount    magMean     magStd  magMin    magLq  magMedian    magUq  \
# idx
# 0       1494.0  36.779625  27.964860    0.16  15.3325     30.915  52.1150
# 1        288.0  40.918090  32.682713    1.23  15.6725     33.695  56.8475
# 2        251.0  37.651514  27.892916    0.28  16.5850     31.380  55.4800
# 3         51.0  54.128431  46.778562    1.88  20.7650     45.490  68.0450
# 4         45.0  37.703111  29.193180    1.88  16.1500     28.630  57.5700
# 5         81.0  43.958395  34.520810    1.88  21.0400     36.690  58.3700
# 6         48.0  43.306250  32.392779    1.29  16.5850     37.885  60.5875
# 7         23.0  32.175652  40.156554    1.25   3.2500     23.290  42.4550
# 8         23.0  33.577826  25.106049    0.75  19.5450     27.620  42.7350
# 9         34.0  39.613235  29.812528    1.88  17.1450     33.270  51.4075
# 10        86.0  39.164186  31.486648    1.88  15.9375     31.405  54.1325
# 11       159.0  32.818113  26.262265    0.75  13.7750     27.470  43.6350
# ...

# %%
vids.join(scores.groupby(['idx']).describe,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-267-13a9acb84dcc> in <module>
# ----> 1 vids.join(scores.groupby(['idx']).describe,axis=1)
#
# TypeError: join() got an unexpected keyword argument 'axis'

# %%
df = pd.concat([vids,thing],axis=1)

# %%
df = df.drop(['magCount','sentCount'],axis=1)

# %%
df.to_csv('files/concat_df_sans_zero.csv')

# %%
foo = pd.read_csv('files/concat_df_sans_zero.csv')

# %%
foo.head()
# Out:
#          date                                              title  class  \
# 0  2013-01-17             Joe Rogan Experience #1 - Brian Redban      2
# 1  2013-01-17             Joe Rogan Experience #2 - Brian Redban      2
# 2  2013-01-17              Joe Rogan Experience #3 - Ari Shaffir      2
# 3  2013-01-17  Joe Rogan Experience #5 - Ari Shaffir & John H...      2
# 4  2013-01-18  Joe Rogan Experience #5 - Ari Shaffir & John H...      2
#
#    viewCount  commentCount  likeCount  dislikeCount      ratio    magMean  \
# 0     673255          2091       6485           175  37.057143  36.779625
# 1     134693           359       1004            68  14.764706  40.918090
# 2     133176           320       1016            66  15.393939  37.651514
# 3      49565            59        343            19  18.052632  54.128431
# 4      33535            48        278            11  25.272727  37.703111
#
#       magStd  ...  magMedian    magUq  magMax  sentMean   sentStd  sentMin  \
# ...

# %%
foo = foo.drop(['Unnamed: 0'],axis=1)

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(data=bar[(foo['class'] > 0)],
                x='viewCount',y='ratio',hue='class',palette=['y','g','b','r','Aqua'])
# Out:
# C:\Users\me\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
bar = foo[(foo.commentCount > 1000) & (foo.viewCount < 8000000)]

# %%
param = ['class','viewCount','']

# %%
foo.max()
# Out:
# date                                                   2019-10-01
# title           Joe Rogan Experience - UFC Recap w/ Brendan Sc...
# class                                                           5
# viewCount                                                26071198
# commentCount                                               123027
# likeCount                                                  530844
# dislikeCount                                                86953
# ratio                                                         inf
# magMean                                                   77.5645
# magStd                                                    70.8311
# magMin                                                       37.1
# magLq                                                       46.72
# magMedian                                                   67.25
# magUq                                                      107.42
# ...

# %%
thing = list(np.isinf(foo['ratio']))
for i in range(len(thing)):
    if thing[i] == True:
        print(i)
# Out:
# 119

# %%
foo.iloc[119]
# Out:
# date                                                   2013-01-23
# title           Joe Rogan Experience #140 - Brendon Walsh (Par...
# class                                                           2
# viewCount                                                    5667
# commentCount                                                    4
# likeCount                                                      62
# dislikeCount                                                    0
# ratio                                                         inf
# magMean                                                   18.8533
# magStd                                                    8.77474
# magMin                                                       8.85
# magLq                                                      15.655
# magMedian                                                   22.46
# magUq                                                      23.855
# ...

# %%
train, test = train_test_split(bar, test_size=0.2)

# %%
bar.columns
drop = ['date','title','ratio']

# %%
reg =  linear_model.LinearRegression()
X_train = train.drop(drop,axis=1)
X_test = test.drop(drop,axis=1)
y_train = train.ratio
y_test = test.ratio
reg.fit(X_train,y_train)
print("y = x *", reg.coef_, "+", reg.intercept_)
# Out:
# y = x * [-7.46991477e-01 -2.29818790e-06 -3.12685618e-04  3.48588361e-04
#  -9.58678584e-05  1.23387011e+00 -6.56204855e-01  1.32204442e+00
#  -5.58737702e-01 -3.58415903e-01 -2.18340536e-01 -1.78381104e-03
#   2.04547145e+02  9.76085817e+00 -3.54332580e+00 -3.48010692e+01
#  -4.06579760e+01 -3.34041496e+01 -1.85110563e+00] + 0.9625001409210245

# %%
prediction = reg.predict(X_test)
print("MSE:", mean_squared_error(y_test, prediction))
print("RMSE:", np.sqrt(mean_squared_error(y_test, prediction)))
print("R^2:", r2_score(y_test, prediction))
print("MAE:", mean_absolute_error(y_test, prediction))
# Out:
# MSE: 36.705161624136124
# RMSE: 6.058478490853634
# R^2: 0.37253744625850105
# MAE: 4.233733695166203

# %%
knn = KNeighborsClassifier(n_neighbors=31)
X_train = train.drop(['class','date','title'],axis=1)
X_test = test.drop(['class','date','title'],axis=1)
y_train = train['class']
y_test = test['class']
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.3875

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 0,  1,  3,  1,  0,  0],
#        [ 0, 16, 19,  1,  0,  0],
#        [ 0, 13, 45,  1,  0,  0],
#        [ 0,  6, 13,  1,  0,  0],
#        [ 0,  6, 19,  1,  0,  0],
#        [ 0,  1, 12,  1,  0,  0]], dtype=int64)

# %%
bar.groupby(['class']).count()
# Out:
#        date  title  viewCount  commentCount  likeCount  dislikeCount  ratio  \
# class
# 0        61     61         61            61         61            61     61
# 1       191    191        191           191        191           191    191
# 2       269    269        269           269        269           269    269
# 3       117    117        117           117        117           117    117
# 4        91     91         91            91         91            91     91
# 5        70     70         70            70         70            70     70
#
#        magMean  magStd  magMin  ...  magMedian  magUq  magMax  sentMean  \
# class                           ...
# 0           61      61      61  ...         61     61      61        61
# 1          191     191     191  ...        191    191     191       191
# 2          269     269     269  ...        269    269     269       269
# 3          117     117     117  ...        117    117     117       117
# ...

# %%
zero = bar[bar['class'] == 0]
one = bar[bar['class'] == 1]
two = bar[bar['class'] == 2]
three = bar[bar['class'] == 3]
four = bar[bar['class'] == 4]
five = bar[bar['class'] == 5]

# %%
arr = [zero,one,two,three,four,five]

for i in range(1,5):
    arr[i] = resample(arr[i], replace=False, n_samples=len(five))
    
foobar = pd.concat([arr[0],arr[1],arr[2],arr[3],arr[4],arr[5]])

foobar['class'].value_counts()
# Out:
# 5    70
# 4    70
# 3    70
# 2    70
# 1    70
# 0    61
# Name: class, dtype: int64

# %%
foobar
# Out:
#             date                                              title  class  \
# 117   2013-01-23       Joe Rogan Experience #138 - Anthony Bourdain      0
# 200   2013-05-29      Joe Rogan Experience #232 - Giorgio Tsoukalos      0
# 279   2013-03-04       Joe Rogan Experience #331 - Dr. Steven Greer      0
# 353   2014-01-07        Joe Rogan Experience #436 - Stefan Molyneux      0
# 441   2014-08-27             Joe Rogan Experience #541 - Mike Baker      0
# 466   2014-10-23             Joe Rogan Experience #566 - Sue Aikens      0
# 501   2015-01-15            Joe Rogan Experience #601 - Katy Bowman      0
# 551   2015-05-22  Joe Rogan Experience #651 - Jordan Gilbert (c9...      0
# 557   2015-06-09         Joe Rogan Experience #657 - Corey Knowlton      0
# 570   2015-07-09   Joe Rogan Experience #670 - Michael A. Wood, Jr.      0
# 609   2015-10-14           Joe Rogan Experience #707 - Michael Dowd      0
# ...

# %%
foobar = foobar.drop(['magMedian','magLq','magUq','magMax','magMin','magStd',
             'sentMedian','sentLq','sentUq','sentMax','sentMin','sentStd'],axis=1)

# %%
X = foobar.drop(['class','date','title'],axis=1)
y = foobar['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
models = [DecisionTreeClassifier(),KNeighborsClassifier(n_neighbors=11),GaussianNB(),MLPClassifier(),SVC()]

# %%
for model in models:
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)

    print(accuracy_score(y_test,y_pred))
    print(f1_score(y_test,y_pred,average='macro'))
    print(precision_score(y_test,y_pred,average='macro'))
    print(recall_score(y_test,y_pred,average='macro'))
    print(confusion_matrix(y_test,y_pred))
# Out:
# 0.3132530120481928
# 0.304313369630974
# 0.30527563252021456
# 0.3295669729880256
# [[2 2 3 3 4 4]
#  [2 8 4 3 2 0]
#  [1 5 4 2 2 1]
#  [2 0 0 3 1 1]
#  [0 3 1 1 5 2]
#  [0 1 3 1 3 4]]
# 0.21686746987951808
# 0.21558523869696178
# 0.25393270944741536
# 0.21211361737677525
# [[3 7 2 4 2 0]
#  [0 5 4 3 2 5]
#  [0 6 3 3 3 0]
#  [2 0 2 1 1 1]
#  [0 3 3 2 3 1]
#  [1 1 2 4 1 3]]
# 0.21686746987951808
# 0.18834044377522638
# 0.29763803448013976
# 0.256390977443609
# [[ 0  1  1  3 12  1]
#  [ 1  1  2  1 13  1]
#  [ 0  0  3  2 10  0]
#  [ 0  0  1  2  4  0]
#  [ 0  0  0  2 10  0]
#  [ 1  0  0  1  8  2]]
# 0.14457831325301204
# 0.042105263157894736
# 0.024096385542168672
# 0.16666666666666666
# [[ 0  0  0  0  0 18]
#  [ 0  0  0  0  0 19]
#  [ 0  0  0  0  0 15]
#  [ 0  0  0  0  0  7]
#  [ 0  0  0  0  0 12]
#  [ 0  0  0  0  0 12]]
# 0.0963855421686747
# 0.04288389513108615
# 0.18089430894308944
# 0.17543859649122806
# [[ 0  0  0 18  0  0]
#  [ 0  1  0 18  0  0]
#  [ 0  0  0 15  0  0]
# ...

# %%
ok = pd.concat([one,two])

# %%
df = foobar.drop(['title','date','class'],axis=1)

# %%
df = foobar[['sentMean','ratio']]

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(df)
df['label'] = kmeans.predict(df)
_p = sns.lmplot("sentMean", "ratio", data=df, fit_reg=False, hue='label', height=10)
